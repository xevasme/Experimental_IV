# %% [markdown]
# ## 📌 Informe de Laboratorio
#
#         Física Experimental IV
#
#
# ### 👥 **Integrantes del grupo:**
#
# - Sebastian Eladio Mena Torres
# - Nombre2
# - Nombre3
# - Nombre4
#
# ---

# %% [markdown]
# ## Definicion de Librerias y Funciones a Utilizar

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from scipy.stats import norm, poisson, binom, uniform, maxwell
from scipy.interpolate import make_interp_spline

# %%
# Función auxiliar para suavizar curvas discretas
def smooth_curve(x, y, resolution=200):
    spline = make_interp_spline(x, y)
    x_smooth = np.linspace(min(x), max(x), resolution)
    y_smooth = spline(x_smooth)

# %% [markdown]
# ---

# %%
O = np.array([13/45,25/40,2/50])

x=np.array([30,40,50,60])
y = norm.cdf(x, loc = 42.25, scale = 5.54)
L=[y[1]-y[0], y[2]-y[1], y[3]-y[2]]
L = np.array(L)


for i in range(3):
    chi = (L[i]-O[i])**2/O[i]
    print(f"Chi cuadrado para i={i}: {chi:.4f}")
# Out:
# Chi cuadrado para i=0: 0.0055
# Chi cuadrado para i=1: 0.0037
# Chi cuadrado para i=2: 0.0405

# %% [markdown]
# # 1 Actividad de recolección de datos experimentales

# %% [markdown]
# ## 1.1 Modelo Normal

# %% [markdown]
# ### Experimento 1: Medición de alturas en una población
# • **Material**: Cinta métrica o regla, cuaderno para registro.
#
# • **Procedimiento**:
# 1. Seleccionar un grupo de personas de una población determinada.
# 2. Medir sus alturas y registrar los valores.
# 3. Calcular la media y la desviación estándar de las alturas.
# 4. Graficar la distribución de las alturas para observar si se ajusta a una distribución normal.

# %%
# Simulación de alturas (en cm) - reemplazar con tus datos reales si los tienes
alturas = np.random.normal(loc=170, scale=7, size=50)  # media = 170 cm, σ = 7 cm

# Cálculo de estadísticos
media = np.mean(alturas)
desviacion = np.std(alturas, ddof=1)

print(f"Media: {media:.2f} cm")
print(f"Desviación estándar: {desviacion:.2f} cm")

# Histograma
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(alturas, bins=10, density=True, alpha=0.6, color='skyblue', edgecolor='black')

# Curva de distribución normal ajustada
x = np.linspace(min(alturas), max(alturas), len(alturas))
pdf = norm.pdf(x, media, desviacion)
plt.plot(x, pdf, 'r--', label='Distribución Normal Ajustada')

plt.title("Distribución de Alturas")
plt.xlabel("Altura (cm)")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Media: 169.64 cm
# Desviación estándar: 8.00 cm

# %% [markdown]
# ### Experimento 2: Conteo de hojas caídas bajo árboles del campus.
#
# • **Procedimiento**:
# 1. Cada grupo elige un árbol.
# 2. Delimitan un área fija (por ejemplo, 1 ${m}^2$) y cuentan cuántas hojas caídas hay.
# 3. Repiten el conteo en otras 3 áreas alrededor del mismo árbol.
# 4. Registran y comparan las medias y varianzas de cada árbol.

# %% [markdown]
# ### Experimento 3: Conteo de personas que pasan por un punto
#
# • **Material**: Cronómetro o celular con temporizador, cuaderno para registro. Ítem
#
# •**Procedimiento**:
# 1. Elegir un punto de observación en un pasillo concurrido o una entrada (por ejemplo, la puerta principal del edificio).
# 2. Observar durante 10 intervalos consecutivos de 1 minuto.
# 3. Contar cuántas personas cruzan un punto de referencia (por ejemplo, una línea imaginaria en el suelo).
# 4. Repetir la actividad en un segundo punto con diferente flujo de personas.
# 5. Comparar las medias y varianzas para evaluar si se ajustan al modelo de Poisson.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2 Modelo Poisson

# %% [markdown]
# ### Experimento 1: Conteo de eventos aleatorios
#
# **Materiales:**
# - Caja opaca o bolsa oscura con 10 bolas (7 negras, 3 blancas)
# - Cronómetro
#
# **Procedimiento:**
# 1. Cada grupo realiza 60 extracciones (una bola cada 2 segundos durante 2 minutos).
# 2. Si la bola es blanca, se considera un "evento detectado".
# 3. Se devuelve la bola antes de cada extracción.
# 4. Se registran los eventos detectados en bloques de 10 extracciones (6 bloques).

# %% [markdown]
# ### Experimento 2: Conteo de hojas caídas bajo árboles del campus
#
# **Procedimiento:**
# 1. Cada grupo elige un árbol.
# 2. Delimitan un área fija (por ejemplo, 1 m²) y cuentan cuántas hojas caídas hay.
# 3. Repiten el conteo en otras 3 áreas alrededor del mismo árbol.
# 4. Registran y comparan las medias y varianzas de cada árbol.

# %% [markdown]
# ### Experimento 3: Conteo de personas que pasan por un punto
#
# **Materiales:**
# - Cronómetro o celular
# - Cuaderno para registro
#
# **Procedimiento:**
# 1. Elegir un punto de observación en un pasillo concurrido o una entrada.
# 2. Observar durante 10 intervalos consecutivos de 1 minuto.
# 3. Contar cuántas personas cruzan una línea imaginaria en el suelo.
# 4. Repetir en un segundo punto con diferente flujo de personas.
# 5. Comparar medias y varianzas para evaluar si se ajustan al modelo de Poisson.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 Modelo Binomial

# %% [markdown]
# ### Experimento 1: Lanzamiento de moneda
#
# **Material:**
# - Moneda
#
# **Procedimiento:**
# 1. Lanzar la moneda 10 veces seguidas.
# 2. Repetir 10 bloques de 10 lanzamientos.
# 3. Registrar cuántas veces salió “cara” en cada bloque.

# %% [markdown]
# ### Experimento 2: Conteo de colores en una bolsa
#
# **Material:**
# - Bolsa opaca con 20 fichas (10 rojas y 10 azules)
# - Cronómetro
#
# **Procedimiento:**
# 1. Cada estudiante saca 1 ficha (sin ver) y la devuelve, repitiendo 15 veces.
# 2. Registrar cuántas veces salió roja.
# 3. Repetir por grupos y comparar los conteos.
# 4. Comparar con la distribución binomial B(n=15, p=0.5).

# %% [markdown]
# ### Experimento 3: Reacción al estímulo
#
# **Material:**
# - Celular con cronómetro
# - Pareja de estudiantes
#
# **Procedimiento:**
# 1. Un estudiante dice “¡ya!” de forma aleatoria (10 veces).
# 2. El otro intenta detener el cronómetro en menos de 0.5 s.
# 3. Registrar si lo logró (“éxito”) o no (“fracaso”).
# 4. Repetir con diferentes estudiantes y comparar los resultados.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.4 Modelo Uniforme

# %% [markdown]
# ### Experimento 1: Lanzamiento de dado
#
# **Material:**
# - Dado común
#
# **Procedimiento:**
# 1. Lanzar el dado 60 veces.
# 2. Contar la frecuencia de cada cara (1 a 6).

# %% [markdown]
# ### Experimento 2: Conteo de colores de autos
#
# **Procedimiento:**
# 1. Observar 50 autos que pasen por una vía cercana.
# 2. Anotar el color principal de cada auto.
# 3. Clasificar en 6 categorías (blanco, negro, rojo, azul, gris, otros).
# 4. Verificar si la distribución es aproximadamente uniforme.

# %% [markdown]
# ### Experimento 3: Captura de sonidos en el entorno
#
# **Material:**
# - Grabadora o app de decibelímetro
#
# **Procedimiento:**
# 1. Caminar durante 5 minutos por una ruta predeterminada.
# 2. Registrar el nivel de ruido (dB) cada 10 segundos.
# 3. Analizar si los valores se distribuyen de forma uniforme o tienen tendencias.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.5 Modelo Maxwell-Boltzmann

# %% [markdown]
# ### Experimento 1: Lanzamiento de dos dados y suma de valores
#
# **Procedimiento:**
# 1. Lanzar dos dados simultáneamente 60 veces.
# 2. Registrar la suma de los valores de ambos dados.
# 3. Graficar el histograma y comparar con la distribución esperada.

# %% [markdown]
# ### Experimento 2: Conteo de personas en movimiento
#
# **Procedimiento:**
# 1. Observar durante 5 minutos en una zona concurrida.
# 2. Contar personas que cruzan una línea cada 30 segundos.
# 3. Estimar “energía” relativa (lento = 1, normal = 2, rápido = 3).
# 4. Registrar frecuencia de cada nivel.
# 5. Comparar con la distribución tipo Maxwell-Boltzmann.

# %% [markdown]
# ### Experimento 3: Velocidad de insectos o aves
#
# **Material:**
# - Cronómetro
# - Cinta métrica o estimación visual
#
# **Procedimiento:**
# 1. Observar insectos o aves que crucen una trayectoria de 3–5 m.
# 2. Medir el tiempo que tardan en recorrerla.
# 3. Calcular velocidades y agrupar en rangos (ej: 0–1 m/s, 1–2 m/s).
# 4. Graficar la distribución y compararla con la Maxwell-Boltzmann.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.6 Pruebas de Hipótesis por Experimento

# %% [markdown]
# ### 1.6.1 Modelo Normal (Alturas / Tiempos / Pesos)
#
# - ¿Los datos experimentales siguen una distribución normal con media $ \mu = \bar{X} $ y desviación estándar $ \sigma = S $? (nivel de significancia  $ \alpha = 0.05 $)
#
#     RESPUESTA :
#
# - ¿Existe diferencia significativa entre la media muestral y un valor teórico esperado?
#
#     RESPUESTA :

# %% [markdown]
# ### 1.6.2 Modelo de Poisson (Eventos / Hojas / Personas)
#
# - ¿La varianza muestral es igual a la media? (es decir, $ \lambda = \bar{X} $)
#
#     RESPUESTA :
#
# - ¿Los conteos siguen una distribución de Poisson con $ \lambda $ estimado?
#
#     RESPUESTA :

# %% [markdown]
# ### 1.6.3 Modelo Binomial (Monedas / Fichas / Éxitos)
#
# - ¿La proporción de éxitos difiere significativamente de $ p = 0.5 $?
#
#     RESPUESTA :
#
# - ¿Los resultados son consistentes con una distribución $ B(n, p) $, donde $ n $ es conocido?
#
#     RESPUESTA :

# %% [markdown]
# ### 1.6.4 Modelo Uniforme (Dados / Colores / Ruido)
#
# - ¿Todos los resultados son equiprobables?
#
#     RESPUESTA :
#
# - ¿Existe preferencia por alguna categoría específica?
#
#     RESPUESTA :

# %% [markdown]
# ###  1.6.5 Modelo Maxwell-Boltzmann (Sumas / Velocidades)
#
# - ¿La distribución de sumas o velocidades coincide con la teórica esperada?
#
#     RESPUESTA :
#
# - ¿La “energía” relativa observada sigue un perfil tipo Maxwell-Boltzmann?
#
#     RESPUESTA :

# %% [markdown]
# #
# ---

# %% [markdown]
#  # 2 Ejemplo Completo de Prueba de Kolmogorov-Smirnov
